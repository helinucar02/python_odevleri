# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('50_Startups.csv')

# %%
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %% [markdown]
# ## Bu veri seti, 50 farklı startup şirketinin çeşitli harcamalarını ve kârlılıklarını içermektedir.
#
# R&D Spend (Ar-Ge Harcaması): Şirketin araştırma ve geliştirme (Ar-Ge) için harcadığı tutar.
# Administration (Yönetim Harcaması): Şirketin yönetim giderleri için harcadığı tutar.
# Marketing Spend (Pazarlama Harcaması): Şirketin pazarlama ve reklam faaliyetleri için harcadığı tutar.
# State (Eyalet): Şirketin faaliyet gösterdiği eyalet (örneğin, New York, California, Florida).
# Profit (Kâr): Şirketin elde ettiği toplam kâr.
# Bu veri seti, startup'ların çeşitli harcama kalemleri ile kârlılıkları arasındaki ilişkileri analiz   etmek için kullanılabilir. Örneğin, Ar-Ge veya pazarlama harcamalarının kârlılık üzerindeki etkisini   incelemek için uygun bir veri setidir.

# %% [markdown]
# ## 1.GÖREV : R&D Harcaması ve Kâr Arasındaki İlişki (Scatter Plot): Ar-Ge harcamaları ile kâr arasındaki ilişkiyi gösteren bir dağılım grafiği.

# %%
# Kodu buraya yazınız 
plt.scatter(x="R&D Spend",y="Profit",data=data)
plt.title("Profit vs R&D Spend")
plt.xlabel("R&D Spend")
plt.ylabel("Profit")
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# ## 2.GÖREV: Yönetim Harcamaları ve Kâr Arasındaki İlişki (Scatter Plot): Yönetim harcamaları ile kâr arasındaki ilişkiyi gösteren bir dağılım grafiği.

# %%
# Kodu buraya yazınız 
plt.scatter(x="Administration",y="Profit",data=data)
plt.title("Administration vs Profit")
plt.xlabel("Administration")
plt.ylabel("Profit")
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# ## 3. GÖREV: Eyaletlere Göre Ortalama Kâr (Bar Chart): Farklı eyaletlerdeki startup'ların ortalama kârlarını karşılaştıran bir çubuk grafik.

# %%
# Kodu buraya yazınız 
df = data.groupby("State")["Profit"].mean()
plt.bar(x=df.index, height=df.values)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ## 4. GÖREV: Harcama Türlerinin Karşılaştırması (Boxplot): R&D, yönetim ve pazarlama harcamalarının dağılımını karşılaştıran bir kutu grafiği.

# %%
# Kodu buraya yazınız 
plt.boxplot([
    data["R&D Spend"],
    data["Administration"],
    data["Marketing Spend"]
])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1895e877380>,
#   <matplotlib.lines.Line2D at 0x1895e874fb0>,
#   <matplotlib.lines.Line2D at 0x1895e848aa0>,
#   <matplotlib.lines.Line2D at 0x1895e7e7fb0>,
#   <matplotlib.lines.Line2D at 0x1895dafdd00>,
#   <matplotlib.lines.Line2D at 0x1895f2f4440>],
#  'caps': [<matplotlib.lines.Line2D at 0x1895e8775c0>,
#   <matplotlib.lines.Line2D at 0x1895e874a40>,
#   <matplotlib.lines.Line2D at 0x1895e84a7e0>,
#   <matplotlib.lines.Line2D at 0x1895e7e75f0>,
#   <matplotlib.lines.Line2D at 0x1895f2f46e0>,
#   <matplotlib.lines.Line2D at 0x1895f2f4b90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1895e877470>,
#   <matplotlib.lines.Line2D at 0x1895e848cb0>,
#   <matplotlib.lines.Line2D at 0x1895dafec30>],
#  'medians': [<matplotlib.lines.Line2D at 0x1895e84a900>,
#   <matplotlib.lines.Line2D at 0x1895e7e7e90>,
#   <matplotlib.lines.Line2D at 0x1895f2f4e00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1895e848d10>,
#   <matplotlib.lines.Line2D at 0x1895daffe60>,
#   <matplotlib.lines.Line2D at 0x1895f2f50d0>],
#  'means': []}
